# %% [markdown]
# # bmi値判定ツール(男性向け)
# ## 【参考: 男性のbmi値】
# - 18.5未満: 痩せすぎ
# - 25以上: 肥満

# %%
# 1. 体重の入力
# %run main/input.py
# Out:
# あなたの身長[m]を入力してください(例: 173cm/1.73m → 1.73) 1.73
# あなたの体重[kg]を入力してください(例: 50kg → 入力: 50) 50
# 【体重】
# あなたの現在の体重は50kgです
# 【bmi】
# あなたのbmiは17です
# 【評価】
# あなたは痩せすぎです。もっと食べましょう。
